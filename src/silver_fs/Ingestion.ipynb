# %%
import sys

sys.path.insert(0,"../lib/")

import utils

# %%
query = utils.import_query(f"{tablename}.sql")

(spark.sql(query)
     .write
     .format("delta")
     .mode("overwrite")
     .option("overwriteSchema", "true"))

if "dtYear" in df.columns:
     writer = writer.partitionBy("dtYear")

# 4. Salva a tabela
writer.saveAsTable(f"silver.f1_world.{tablename}")
